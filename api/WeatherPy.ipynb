# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key
lat_0 = []
lng_0 = []
temp = []
humid = []
cloud = []
wind_speed = []
country = []
date = []
max_temp = []
city_0 = []

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?appid=" + api_key + "&units=imperial&q="

print("Beginning Data Retrieval\n-----------------------------")

i_test = 0
j_test = 1
for city in cities:
    url_query = url + city
    response = requests.get(url_query).json()
    try:
        lat_0.append(response['coord']['lat'])
        lng_0.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        humid.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        max_temp.append(response['main']['temp_max'])
        city_0.append(city)
        print(f"Processing Record {i_test} of Set {j_test} | {city}")
        print(url_query)
        i_test += 1
        if (i_test == 50):
            i_test = 0
            j_test += 1
    except KeyError:
        print("City not found. Skipping...")

print("-----------------------------\nData Retrieval Complete\n-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=rikitea
# Processing Record 1 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=hobart
# Processing Record 2 of Set 1 | pong
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=pong
# Processing Record 3 of Set 1 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=ilulissat
# Processing Record 4 of Set 1 | buin
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=buin
# Processing Record 5 of Set 1 | iraray
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=imperial&q=iraray
# ...

# %%
df = pd.DataFrame({"City":city_0,
                   "Cloudiness":cloud,
                   "Country":country,
                   "Date":date,
                   "Humidity":humid,
                   "Lat":lat_0,
                   "Lng":lng_0,
                   "Max Temp":max_temp,
                   "Wind Speed":wind_speed})
df.count()
# Out:
# City          564
# Cloudiness    564
# Country       564
# Date          564
# Humidity      564
# Lat           564
# Lng           564
# Max Temp      564
# Wind Speed    564
# dtype: int64

# %%
df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    rikitea          12      PF  1533709323       100 -23.12 -134.97
# 1     hobart          40      AU  1533708000        46 -42.88  147.33
# 2       pong          75      TH  1533706200        58  12.95  100.98
# 3  ilulissat          92      GL  1533707400        50  69.22  -51.10
# 4       buin           0      CL  1533704400        80 -33.73  -70.74
#
#    Max Temp  Wind Speed
# 0     73.67       11.54
# 1     53.60       10.29
# 2     87.80       10.29
# 3     57.20       19.46
# 4     39.20        3.36

# %%
plt.figure()
plt.scatter(df["Lat"], df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (08/07/18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-80, 100)
plt.ylim(-100, 150)

# Save the figure
plt.savefig("temp_max.png")

# Show plot
plt.show()

# %%
plt.figure()
plt.scatter(df["Lat"], df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (08/07/18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-80, 100)
plt.ylim(-20, 120)

# Save the figure
plt.savefig("humidity.png")

# Show plot
plt.show()

# %%
plt.figure()
plt.scatter(df["Lat"], df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (08/07/18)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-80, 100)
plt.ylim(-20, 120)

# Save the figure
plt.savefig("cloudiness.png")

# Show plot
plt.show()

# %%
plt.figure()
plt.scatter(df["Lat"], df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (08/07/18)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-80, 100)
plt.ylim(-5, 40)

# Save the figure
plt.savefig("wind_speed.png")

# Show plot
plt.show()

# %%
# save .csv file
df.to_csv("weather.csv", index=False, header=True)

# %%
# Analysis of observable trends based on the data

#1.Lower Absolute value of latitude shows higher MAX temperature, 
#while higer absolute value of latitude shows lower MAX temperature.
#2.Humidity has no relationship with Latitude.
#3.Cloudiness has no relationship with Latitude.
#4.Wind speed has little relationship with latitude.
#5.Cloudiness region of 40%-60% include few cities of all latitudes.
